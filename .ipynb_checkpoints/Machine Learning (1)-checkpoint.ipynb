# %%
import pandas as pd 
import numpy as np
import os
import seaborn as sns
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
house = "Resources/Final_rent_homevalue.csv"

# %%
house = pd.read_csv(house, encoding = "ISO-8859-1")

# %%
house.head()
# Out:
#    zipcode    primarycity                     city        date       rent  \
# 0    91710          Chino            Riverside, CA  2014-01-01  $1,810.00
# 1    28078   Huntersville            Charlotte, NC  2014-01-01  $1,205.00
# 2    89074      Henderson            Las Vegas, NV  2014-01-01  $1,040.00
# 3    20910  Silver Spring           Washington, DC  2014-01-01  $1,830.00
# 4    55104     Saint Paul  Minneapolis-St Paul, MN  2014-01-01  $1,087.00
#
#    latitude  longitude                 county  year  month    homevalue
# 0     34.00    -117.68  San Bernardino County  2014      1  $393,085.00
# 1     35.41     -80.84     Mecklenburg County  2014      1  $252,566.00
# 2     36.03    -115.07           Clark County  2014      1  $216,309.00
# 3     39.00     -77.04      Montgomery County  2014      1  $541,022.00
# 4     44.95     -93.16          Ramsey County  2014      1  $190,597.00

# %%
house["rent"] = house["rent"].str.replace("$", "")
house["rent"] = house["rent"].str.replace(",", "")
house["rent"] = house["rent"].astype(float)
# Out:
# C:\Users\bethf\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.

# %%
house.columns
# Out:
# Index(['zipcode', 'primarycity', 'city', 'date', 'rent', 'latitude',
#        'longitude', 'county', 'year', 'month', 'homevalue'],
#       dtype='object')

# %%
house["homevalue"] = house["homevalue"].str.replace("$", "")
house["homevalue"] = house["homevalue"].str.replace(",", "")
house["homevalue"] = house["homevalue"].astype(float)
# Out:
# C:\Users\bethf\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216608 entries, 0 to 216607
# Data columns (total 11 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   zipcode      216608 non-null  int64
#  1   primarycity  216608 non-null  object
#  2   city         216608 non-null  object
#  3   date         216608 non-null  object
#  4   rent         216608 non-null  float64
#  5   latitude     216608 non-null  float64
#  6   longitude    216608 non-null  float64
#  7   county       216509 non-null  object
#  8   year         216608 non-null  int64
#  9   month        216608 non-null  int64
#  10  homevalue    216608 non-null  float64
# dtypes: float64(4), int64(3), object(4)
# memory usage: 18.2+ MB

# %%
house.describe()
# Out:
#              zipcode           rent       latitude      longitude  \
# count  216608.000000  216608.000000  216608.000000  216608.000000
# mean    54924.910830    1667.264381      35.505987     -94.443329
# std     30846.015989     835.472886       5.351203      17.671219
# min      1604.000000      84.000000      21.270000    -158.080000
# 25%     30022.000000    1215.000000      32.790000    -112.310000
# 50%     48326.000000    1503.000000      34.300000     -87.620000
# 75%     85653.000000    1937.000000      39.690000     -80.200000
# max     99206.000000   30255.000000      48.180000     -70.660000
#
#                 year          month     homevalue
# count  216608.000000  216608.000000  2.166080e+05
# mean     2017.683437       6.377553  4.384376e+05
# std         2.361714       3.479039  4.043536e+05
# min      2014.000000       1.000000  1.943100e+04
# 25%      2016.000000       3.000000  2.112858e+05
# 50%      2018.000000       6.000000  3.163100e+05
# 75%      2020.000000       9.000000  5.126048e+05
# max      2022.000000      12.000000  5.990842e+06

# %%
housevalue = house["rent"]
box_df = house.pivot(columns='year',values='rent')
box_dict =[ v.dropna() for k,v in box_df.iterrows() ]
box_dict
# Out:
# [year
#  2014    1810.0
#  Name: 0, dtype: float64, year
#  2014    1205.0
#  Name: 1, dtype: float64, year
#  2014    1040.0
#  Name: 2, dtype: float64, year
#  2014    1830.0
#  Name: 3, dtype: float64, year
#  2014    1087.0
#  Name: 4, dtype: float64, year
#  2014    1218.0
#  Name: 5, dtype: float64, year
#  2014    1157.0
#  Name: 6, dtype: float64, year
#  2014    2251.0
#  Name: 7, dtype: float64, year
#  2014    1235.0
#  Name: 8, dtype: float64, year
#  2014    2688.0
#  Name: 9, dtype: float64, year
#  2014    1179.0
#  Name: 10, dtype: float64, year
#  2014    972.0
#  Name: 11, dtype: float64, year
#  2014    666.0
#  Name: 12, dtype: float64, year
#  2014    1321.0
#  Name: 13, dtype: float64, year
#  2014    2137.0
#  Name: 14, dtype: float64, year
#  2014    1152.0
#  Name: 15, dtype: float64, year
#  2014    1698.0
#  Name: 16, dtype: float64, year
#  2014    1554.0
#  Name: 17, dtype: float64, year
#  2014    1235.0
#  Name: 18, dtype: float64, year
#  2014    1604.0
#  Name: 19, dtype: float64, year
#  2014    1198.0
#  Name: 20, dtype: float64, year
#  2014    1345.0
#  Name: 21, dtype: float64, year
#  2014    2702.0
#  Name: 22, dtype: float64, year
#  2014    2434.0
#  Name: 23, dtype: float64, year
#  2014    959.0
#  Name: 24, dtype: float64, year
#  2014    1443.0
#  Name: 25, dtype: float64, year
#  2014    1286.0
#  Name: 26, dtype: float64, year
#  2014    1093.0
#  Name: 27, dtype: float64, year
#  2014    979.0
#  Name: 28, dtype: float64, year
#  2014    1939.0
#  Name: 29, dtype: float64, year
#  2014    984.0
#  Name: 30, dtype: float64, year
#  2014    1525.0
#  Name: 31, dtype: float64, year
#  2014    1757.0
#  Name: 32, dtype: float64, year
#  2014    1427.0
#  Name: 33, dtype: float64, year
#  2014    1002.0
#  Name: 34, dtype: float64, year
#  2014    801.0
#  Name: 35, dtype: float64, year
#  2014    1629.0
#  Name: 36, dtype: float64, year
#  2014    1254.0
#  Name: 37, dtype: float64, year
#  2014    1048.0
#  Name: 38, dtype: float64, year
#  2014    1419.0
#  Name: 39, dtype: float64, year
#  2014    833.0
#  Name: 40, dtype: float64, year
#  2014    1266.0
#  Name: 41, dtype: float64, year
#  2014    1552.0
#  Name: 42, dtype: float64, year
#  2014    1094.0
#  Name: 43, dtype: float64, year
#  2014    1723.0
#  Name: 44, dtype: float64, year
#  2014    1554.0
#  Name: 45, dtype: float64, year
#  2014    1099.0
#  Name: 46, dtype: float64, year
#  2014    995.0
#  Name: 47, dtype: float64, year
#  2014    1733.0
#  Name: 48, dtype: float64, year
#  2014    1261.0
#  Name: 49, dtype: float64, year
#  2014    846.0
#  Name: 50, dtype: float64, year
#  2014    920.0
#  Name: 51, dtype: float64, year
#  2014    2080.0
#  Name: 52, dtype: float64, year
#  2014    1111.0
#  Name: 53, dtype: float64, year
#  2014    1470.0
#  Name: 54, dtype: float64, year
#  2014    2757.0
#  Name: 55, dtype: float64, year
#  2014    1100.0
#  Name: 56, dtype: float64, year
#  2014    1631.0
#  Name: 57, dtype: float64, year
#  2014    805.0
#  Name: 58, dtype: float64, year
#  2014    1995.0
#  Name: 59, dtype: float64, year
#  2015    1447.0
#  Name: 60, dtype: float64, year
#  2015    1301.0
#  Name: 61, dtype: float64, year
#  2015    1002.0
#  Name: 62, dtype: float64, year
#  2015    916.0
#  Name: 63, dtype: float64, year
#  2015    980.0
#  Name: 64, dtype: float64, year
#  2015    1475.0
#  Name: 65, dtype: float64, year
#  2015    855.0
#  Name: 66, dtype: float64, year
#  2015    823.0
#  Name: 67, dtype: float64, year
#  2015    2473.0
#  Name: 68, dtype: float64, year
#  2015    1403.0
#  Name: 69, dtype: float64, year
#  2015    1014.0
#  Name: 70, dtype: float64, year
#  2015    2508.0
#  Name: 71, dtype: float64, year
#  2015    1899.0
#  Name: 72, dtype: float64, year
#  2015    2334.0
#  Name: 73, dtype: float64, year
#  2015    998.0
#  Name: 74, dtype: float64, year
#  2015    1624.0
#  Name: 75, dtype: float64, year
#  2015    998.0
#  Name: 76, dtype: float64, year
#  2015    1199.0
#  Name: 77, dtype: float64, year
#  2015    1405.0
#  Name: 78, dtype: float64, year
#  2015    2493.0
#  Name: 79, dtype: float64, year
#  2015    1374.0
#  Name: 80, dtype: float64, year
#  2015    1416.0
#  Name: 81, dtype: float64, year
#  2015    2188.0
#  Name: 82, dtype: float64, year
#  2015    1214.0
#  Name: 83, dtype: float64, year
#  2015    1288.0
#  Name: 84, dtype: float64, year
#  2015    1188.0
#  Name: 85, dtype: float64, year
#  2015    910.0
#  Name: 86, dtype: float64, year
#  2015    1221.0
#  Name: 87, dtype: float64, year
#  2015    1083.0
#  Name: 88, dtype: float64, year
#  2015    2054.0
#  Name: 89, dtype: float64, year
#  2015    1719.0
#  Name: 90, dtype: float64, year
#  2015    1878.0
#  Name: 91, dtype: float64, year
#  2015    1547.0
#  Name: 92, dtype: float64, year
#  2015    776.0
#  Name: 93, dtype: float64, year
#  2015    1314.0
#  Name: 94, dtype: float64, year
#  2015    1319.0
#  Name: 95, dtype: float64, year
#  2015    727.0
#  Name: 96, dtype: float64, year
#  2015    600.0
#  Name: 97, dtype: float64, year
#  2015    1094.0
#  Name: 98, dtype: float64, year
#  2015    1132.0
#  Name: 99, dtype: float64, year
#  2015    1369.0
#  Name: 100, dtype: float64, year
#  2015    1236.0
#  Name: 101, dtype: float64, year
#  2015    818.0
#  Name: 102, dtype: float64, year
#  2015    1026.0
#  Name: 103, dtype: float64, year
#  2015    1548.0
#  Name: 104, dtype: float64, year
#  2015    1547.0
#  Name: 105, dtype: float64, year
#  2015    1120.0
#  Name: 106, dtype: float64, year
#  2015    1300.0
#  Name: 107, dtype: float64, year
#  2015    997.0
#  Name: 108, dtype: float64, year
#  2015    997.0
#  Name: 109, dtype: float64, year
#  2015    1316.0
#  Name: 110, dtype: float64, year
#  2015    1068.0
#  Name: 111, dtype: float64, year
#  2015    1167.0
#  Name: 112, dtype: float64, year
#  2015    1062.0
#  Name: 113, dtype: float64, year
#  2015    1556.0
#  Name: 114, dtype: float64, year
#  2015    2599.0
#  Name: 115, dtype: float64, year
#  2015    1094.0
#  Name: 116, dtype: float64, year
#  2015    1628.0
#  Name: 117, dtype: float64, year
#  2015    1618.0
#  Name: 118, dtype: float64, year
#  2015    2212.0
#  Name: 119, dtype: float64, year
#  2015    1200.0
#  Name: 120, dtype: float64, year
#  2015    1059.0
#  Name: 121, dtype: float64, year
#  2015    1761.0
#  Name: 122, dtype: float64, year
#  2015    1901.0
#  Name: 123, dtype: float64, year
#  2015    1828.0
#  Name: 124, dtype: float64, year
#  2015    1880.0
#  Name: 125, dtype: float64, year
#  2015    4055.0
#  Name: 126, dtype: float64, year
#  2015    954.0
#  Name: 127, dtype: float64, year
#  2015    2611.0
#  Name: 128, dtype: float64, year
#  2015    1631.0
#  Name: 129, dtype: float64, year
#  2015    1742.0
#  Name: 130, dtype: float64, year
#  2015    1128.0
#  Name: 131, dtype: float64, year
#  2015    1048.0
#  Name: 132, dtype: float64, year
#  2016    1120.0
#  Name: 133, dtype: float64, year
#  2016    2260.0
#  Name: 134, dtype: float64, year
#  2016    1339.0
#  Name: 135, dtype: float64, year
#  2016    2011.0
#  Name: 136, dtype: float64, year
#  2016    1612.0
#  Name: 137, dtype: float64, year
#  2016    1973.0
#  Name: 138, dtype: float64, year
#  2016    726.0
#  Name: 139, dtype: float64, year
#  2016    1113.0
#  Name: 140, dtype: float64, year
#  2016    1175.0
#  Name: 141, dtype: float64, year
#  2016    1275.0
#  Name: 142, dtype: float64, year
#  2016    3475.0
#  Name: 143, dtype: float64, year
#  2016    724.0
#  Name: 144, dtype: float64, year
#  2016    1394.0
#  Name: 145, dtype: float64, year
#  2016    1086.0
#  Name: 146, dtype: float64, year
#  2016    1184.0
#  Name: 147, dtype: float64, year
#  2016    3527.0
#  Name: 148, dtype: float64, year
#  2016    1072.0
#  Name: 149, dtype: float64, year
#  2016    1274.0
#  Name: 150, dtype: float64, year
#  2016    1084.0
#  Name: 151, dtype: float64, year
#  2016    938.0
#  Name: 152, dtype: float64, year
#  2016    1341.0
#  Name: 153, dtype: float64, year
#  2016    1904.0
#  Name: 154, dtype: float64, year
#  2016    2623.0
#  Name: 155, dtype: float64, year
#  2016    2557.0
#  Name: 156, dtype: float64, year
#  2016    2424.0
#  Name: 157, dtype: float64, year
#  2016    1284.0
#  Name: 158, dtype: float64, year
#  2016    1533.0
#  Name: 159, dtype: float64, year
#  2016    1384.0
#  Name: 160, dtype: float64, year
#  2016    2098.0
#  Name: 161, dtype: float64, year
#  2016    1312.0
#  Name: 162, dtype: float64, year
#  2016    1374.0
#  Name: 163, dtype: float64, year
#  2016    1428.0
#  Name: 164, dtype: float64, year
#  2016    1631.0
#  Name: 165, dtype: float64, year
#  2016    883.0
#  Name: 166, dtype: float64, year
#  2016    1348.0
#  Name: 167, dtype: float64, year
#  2016    1269.0
#  Name: 168, dtype: float64, year
#  2016    2964.0
#  Name: 169, dtype: float64, year
#  2016    1446.0
#  Name: 170, dtype: float64, year
#  2016    1801.0
#  Name: 171, dtype: float64, year
#  2016    1330.0
#  Name: 172, dtype: float64, year
#  2016    1981.0
#  Name: 173, dtype: float64, year
#  2016    1007.0
#  Name: 174, dtype: float64, year
#  2016    576.0
#  Name: 175, dtype: float64, year
#  2016    1793.0
#  Name: 176, dtype: float64, year
#  2016    728.0
#  Name: 177, dtype: float64, year
#  2016    1288.0
#  Name: 178, dtype: float64, year
#  2016    2126.0
#  Name: 179, dtype: float64, year
#  2016    2249.0
#  Name: 180, dtype: float64, year
#  2016    1791.0
#  Name: 181, dtype: float64, year
#  2016    2448.0
#  Name: 182, dtype: float64, year
#  2016    1095.0
#  Name: 183, dtype: float64, year
#  2016    2344.0
#  Name: 184, dtype: float64, year
#  2016    1096.0
#  Name: 185, dtype: float64, year
#  2016    856.0
#  Name: 186, dtype: float64, year
#  2016    1397.0
#  Name: 187, dtype: float64, year
#  2017    1883.0
#  Name: 188, dtype: float64, year
#  2017    1347.0
#  Name: 189, dtype: float64, year
#  2017    2403.0
#  Name: 190, dtype: float64, year
#  2017    2545.0
#  Name: 191, dtype: float64, year
#  2017    5005.0
#  Name: 192, dtype: float64, year
#  2017    1988.0
#  Name: 193, dtype: float64, year
#  2017    1312.0
#  Name: 194, dtype: float64, year
#  2017    1438.0
#  Name: 195, dtype: float64, year
#  2017    1803.0
#  Name: 196, dtype: float64, year
#  2017    1415.0
#  Name: 197, dtype: float64, year
#  2017    988.0
#  Name: 198, dtype: float64, year
#  2017    1187.0
#  Name: 199, dtype: float64, year
#  2017    635.0
#  Name: 200, dtype: float64, year
#  2017    1221.0
#  Name: 201, dtype: float64, year
#  2017    958.0
#  Name: 202, dtype: float64, year
#  2017    838.0
#  Name: 203, dtype: float64, year
#  2017    2271.0
#  Name: 204, dtype: float64, year
#  2017    2399.0
#  Name: 205, dtype: float64, year
#  2017    2859.0
#  Name: 206, dtype: float64, year
#  2017    1463.0
#  Name: 207, dtype: float64, year
#  2017    1838.0
#  Name: 208, dtype: float64, year
#  2017    1673.0
#  Name: 209, dtype: float64, year
#  2017    1657.0
#  Name: 210, dtype: float64, year
#  2017    1257.0
#  Name: 211, dtype: float64, year
#  2017    1928.0
#  Name: 212, dtype: float64, year
#  2017    1136.0
#  Name: 213, dtype: float64, year
#  2017    1629.0
#  Name: 214, dtype: float64, year
#  2017    880.0
#  Name: 215, dtype: float64, year
#  2017    1549.0
#  Name: 216, dtype: float64, year
#  2017    2196.0
#  Name: 217, dtype: float64, year
#  2017    1314.0
#  Name: 218, dtype: float64, year
#  2017    1762.0
#  Name: 219, dtype: float64, year
#  2017    2022.0
#  Name: 220, dtype: float64, year
#  2017    1314.0
#  Name: 221, dtype: float64, year
#  2017    2297.0
#  Name: 222, dtype: float64, year
#  2017    2338.0
#  Name: 223, dtype: float64, year
#  2017    1449.0
#  Name: 224, dtype: float64, year
#  2017    1040.0
#  Name: 225, dtype: float64, year
#  2017    1310.0
#  Name: 226, dtype: float64, year
#  2017    1410.0
#  Name: 227, dtype: float64, year
#  2017    1474.0
#  Name: 228, dtype: float64, year
#  2017    854.0
#  Name: 229, dtype: float64, year
#  2017    1791.0
#  Name: 230, dtype: float64, year
#  2017    1308.0
#  Name: 231, dtype: float64, year
#  2017    1399.0
#  Name: 232, dtype: float64, year
#  2017    1183.0
#  Name: 233, dtype: float64, year
#  2017    1105.0
#  Name: 234, dtype: float64, year
#  2017    2933.0
#  Name: 235, dtype: float64, year
#  2017    1877.0
#  Name: 236, dtype: float64, year
#  2017    1030.0
#  Name: 237, dtype: float64, year
#  2017    1498.0
#  Name: 238, dtype: float64, year
#  2017    1989.0
#  Name: 239, dtype: float64, year
#  2017    1050.0
#  Name: 240, dtype: float64, year
#  2017    1630.0
#  Name: 241, dtype: float64, year
#  2017    2110.0
#  Name: 242, dtype: float64, year
#  2017    1381.0
#  Name: 243, dtype: float64, year
#  2017    767.0
#  Name: 244, dtype: float64, year
#  2017    1124.0
#  Name: 245, dtype: float64, year
#  2017    1848.0
#  Name: 246, dtype: float64, year
#  2017    969.0
#  Name: 247, dtype: float64, year
#  2017    737.0
#  Name: 248, dtype: float64, year
#  2017    1506.0
#  Name: 249, dtype: float64, year
#  2017    1306.0
#  Name: 250, dtype: float64, year
#  2017    3244.0
#  Name: 251, dtype: float64, year
#  2017    706.0
#  Name: 252, dtype: float64, year
#  2017    2224.0
#  Name: 253, dtype: float64, year
#  2017    1713.0
#  Name: 254, dtype: float64, year
#  2017    1493.0
#  Name: 255, dtype: float64, year
#  2017    3341.0
#  Name: 256, dtype: float64, year
#  2017    1493.0
#  Name: 257, dtype: float64, year
#  2017    920.0
#  Name: 258, dtype: float64, year
#  2017    1061.0
#  Name: 259, dtype: float64, year
#  2017    996.0
#  Name: 260, dtype: float64, year
#  2017    2226.0
#  Name: 261, dtype: float64, year
#  2017    1224.0
#  Name: 262, dtype: float64, year
#  2017    1567.0
#  Name: 263, dtype: float64, year
#  2017    1063.0
#  Name: 264, dtype: float64, year
#  2017    992.0
#  Name: 265, dtype: float64, year
#  2017    2074.0
#  Name: 266, dtype: float64, year
#  2017    1496.0
#  Name: 267, dtype: float64, year
#  2018    1996.0
#  Name: 268, dtype: float64, year
#  2018    1855.0
#  Name: 269, dtype: float64, year
#  2018    1878.0
#  Name: 270, dtype: float64, year
#  2018    945.0
#  Name: 271, dtype: float64, year
#  2018    1742.0
#  Name: 272, dtype: float64, year
#  2018    1475.0
#  Name: 273, dtype: float64, year
#  2018    1498.0
#  Name: 274, dtype: float64, year
#  2018    1113.0
#  Name: 275, dtype: float64, year
#  2018    2880.0
#  Name: 276, dtype: float64, year
#  2018    1602.0
#  Name: 277, dtype: float64, year
#  2018    2850.0
#  Name: 278, dtype: float64, year
#  2018    1003.0
#  Name: 279, dtype: float64, year
#  2018    2272.0
#  Name: 280, dtype: float64, year
#  2018    1395.0
#  Name: 281, dtype: float64, year
#  2018    1536.0
#  Name: 282, dtype: float64, year
#  2018    1792.0
#  Name: 283, dtype: float64, year
#  2018    1030.0
#  Name: 284, dtype: float64, year
#  2018    1010.0
#  Name: 285, dtype: float64, year
#  2018    1734.0
#  Name: 286, dtype: float64, year
#  2018    1673.0
#  Name: 287, dtype: float64, year
#  2018    2400.0
#  Name: 288, dtype: float64, year
#  2018    2137.0
#  Name: 289, dtype: float64, year
#  2018    1282.0
#  Name: 290, dtype: float64, year
#  2018    2231.0
#  Name: 291, dtype: float64, year
#  2018    2463.0
#  Name: 292, dtype: float64, year
#  2018    822.0
#  Name: 293, dtype: float64, year
#  2018    851.0
#  Name: 294, dtype: float64, year
#  2018    1846.0
#  Name: 295, dtype: float64, year
#  2018    3421.0
#  Name: 296, dtype: float64, year
#  2018    940.0
#  Name: 297, dtype: float64, year
#  2018    1290.0
#  Name: 298, dtype: float64, year
#  2018    1196.0
#  Name: 299, dtype: float64, year
#  2018    2230.0
#  Name: 300, dtype: float64, year
#  2018    1834.0
#  Name: 301, dtype: float64, year
#  2018    1843.0
#  Name: 302, dtype: float64, year
#  2018    2010.0
#  Name: 303, dtype: float64, year
#  2018    1574.0
#  Name: 304, dtype: float64, year
#  2018    1383.0
#  Name: 305, dtype: float64, year
#  2018    2904.0
#  Name: 306, dtype: float64, year
#  2018    1156.0
#  Name: 307, dtype: float64, year
#  2018    1643.0
#  Name: 308, dtype: float64, year
#  2018    1593.0
#  Name: 309, dtype: float64, year
#  2018    1193.0
#  Name: 310, dtype: float64, year
#  2018    2401.0
#  Name: 311, dtype: float64, year
#  2018    1462.0
#  Name: 312, dtype: float64, year
#  2018    1411.0
#  Name: 313, dtype: float64, year
#  2018    1727.0
#  Name: 314, dtype: float64, year
#  2018    1280.0
#  Name: 315, dtype: float64, year
#  2018    1522.0
#  Name: 316, dtype: float64, year
#  2018    1608.0
#  Name: 317, dtype: float64, year
#  2018    1158.0
#  Name: 318, dtype: float64, year
#  2018    1145.0
#  Name: 319, dtype: float64, year
#  2018    1019.0
#  Name: 320, dtype: float64, year
#  2018    1418.0
#  Name: 321, dtype: float64, year
#  2018    1515.0
#  Name: 322, dtype: float64, year
#  2018    1553.0
#  Name: 323, dtype: float64, year
#  2018    1256.0
#  Name: 324, dtype: float64, year
#  2018    2023.0
#  Name: 325, dtype: float64, year
#  2018    1596.0
#  Name: 326, dtype: float64, year
#  2018    1705.0
#  Name: 327, dtype: float64, year
#  2019    2335.0
#  Name: 328, dtype: float64, year
#  2019    2052.0
#  Name: 329, dtype: float64, year
#  2019    995.0
#  Name: 330, dtype: float64, year
#  2019    1196.0
#  Name: 331, dtype: float64, year
#  2019    1374.0
#  Name: 332, dtype: float64, year
#  2019    1283.0
#  Name: 333, dtype: float64, year
#  2019    918.0
#  Name: 334, dtype: float64, year
#  2019    1393.0
#  Name: 335, dtype: float64, year
#  2019    2885.0
#  Name: 336, dtype: float64, year
#  2019    1443.0
#  Name: 337, dtype: float64, year
#  2019    2297.0
#  Name: 338, dtype: float64, year
#  2019    1414.0
#  Name: 339, dtype: float64, year
#  2019    2996.0
#  Name: 340, dtype: float64, year
#  2019    2945.0
#  Name: 341, dtype: float64, year
#  2019    1676.0
#  Name: 342, dtype: float64, year
#  2019    1667.0
#  Name: 343, dtype: float64, year
#  2019    904.0
#  Name: 344, dtype: float64, year
#  2019    2881.0
#  Name: 345, dtype: float64, year
#  2019    2324.0
#  Name: 346, dtype: float64, year
#  2019    1047.0
#  Name: 347, dtype: float64, year
#  2019    1407.0
#  Name: 348, dtype: float64, year
#  2019    1815.0
#  Name: 349, dtype: float64, year
#  2019    1210.0
#  Name: 350, dtype: float64, year
#  2019    1110.0
#  Name: 351, dtype: float64, year
#  2019    1886.0
#  Name: 352, dtype: float64, year
#  2019    2727.0
#  Name: 353, dtype: float64, year
#  2019    1534.0
#  Name: 354, dtype: float64, year
#  2019    2098.0
#  Name: 355, dtype: float64, year
#  2019    1285.0
#  Name: 356, dtype: float64, year
#  2019    2170.0
#  Name: 357, dtype: float64, year
#  2019    1579.0
#  Name: 358, dtype: float64, year
#  2019    1260.0
#  Name: 359, dtype: float64, year
#  2019    1382.0
#  Name: 360, dtype: float64, year
#  2019    1722.0
#  Name: 361, dtype: float64, year
#  2019    1406.0
#  Name: 362, dtype: float64, year
#  2019    1498.0
#  Name: 363, dtype: float64, year
#  2019    1195.0
#  Name: 364, dtype: float64, year
#  2019    3204.0
#  Name: 365, dtype: float64, year
#  2019    1846.0
#  Name: 366, dtype: float64, year
#  2019    1841.0
#  Name: 367, dtype: float64, year
#  2019    1433.0
#  Name: 368, dtype: float64, year
#  2019    2144.0
#  Name: 369, dtype: float64, year
#  2019    1601.0
#  Name: 370, dtype: float64, year
#  2019    1507.0
#  Name: 371, dtype: float64, year
#  2019    1353.0
#  Name: 372, dtype: float64, year
#  2019    1329.0
#  Name: 373, dtype: float64, year
#  2019    2523.0
#  Name: 374, dtype: float64, year
#  2019    1171.0
#  Name: 375, dtype: float64, year
#  2019    2918.0
#  Name: 376, dtype: float64, year
#  2019    6377.0
#  Name: 377, dtype: float64, year
#  2019    1626.0
#  Name: 378, dtype: float64, year
#  2019    1383.0
#  Name: 379, dtype: float64, year
#  2019    1735.0
#  Name: 380, dtype: float64, year
#  2019    1306.0
#  Name: 381, dtype: float64, year
#  2019    1458.0
#  Name: 382, dtype: float64, year
#  2019    2093.0
#  Name: 383, dtype: float64, year
#  2019    2817.0
#  Name: 384, dtype: float64, year
#  2019    1083.0
#  Name: 385, dtype: float64, year
#  2019    2050.0
#  Name: 386, dtype: float64, year
#  2019    1951.0
#  Name: 387, dtype: float64, year
#  2019    803.0
#  Name: 388, dtype: float64, year
#  2019    1574.0
#  Name: 389, dtype: float64, year
#  2019    1663.0
#  Name: 390, dtype: float64, year
#  2019    1047.0
#  Name: 391, dtype: float64, year
#  2019    1858.0
#  Name: 392, dtype: float64, year
#  2019    2350.0
#  Name: 393, dtype: float64, year
#  2019    1276.0
#  Name: 394, dtype: float64, year
#  2019    2222.0
#  Name: 395, dtype: float64, year
#  2019    1433.0
#  Name: 396, dtype: float64, year
#  2019    1887.0
#  Name: 397, dtype: float64, year
#  2019    836.0
#  Name: 398, dtype: float64, year
#  2019    1391.0
#  Name: 399, dtype: float64, year
#  2019    974.0
#  Name: 400, dtype: float64, year
#  2019    847.0
#  Name: 401, dtype: float64, year
#  2019    1254.0
#  Name: 402, dtype: float64, year
#  2019    2012.0
#  Name: 403, dtype: float64, year
#  2019    1296.0
#  Name: 404, dtype: float64, year
#  2020    2224.0
#  Name: 405, dtype: float64, year
#  2020    1894.0
#  Name: 406, dtype: float64, year
#  2020    2907.0
#  Name: 407, dtype: float64, year
#  2020    1358.0
#  Name: 408, dtype: float64, year
#  2020    3407.0
#  Name: 409, dtype: float64, year
#  2020    1710.0
#  Name: 410, dtype: float64, year
#  2020    1506.0
#  Name: 411, dtype: float64, year
#  2020    2097.0
#  Name: 412, dtype: float64, year
#  2020    2048.0
#  Name: 413, dtype: float64, year
#  2020    2915.0
#  Name: 414, dtype: float64, year
#  2020    1654.0
#  Name: 415, dtype: float64, year
#  2020    2416.0
#  Name: 416, dtype: float64, year
#  2020    1507.0
#  Name: 417, dtype: float64, year
#  2020    1513.0
#  Name: 418, dtype: float64, year
#  2020    1744.0
#  Name: 419, dtype: float64, year
#  2020    1198.0
#  Name: 420, dtype: float64, year
#  2020    1381.0
#  Name: 421, dtype: float64, year
#  2020    1575.0
#  Name: 422, dtype: float64, year
#  2020    1463.0
#  Name: 423, dtype: float64, year
#  2020    1460.0
#  Name: 424, dtype: float64, year
#  2020    1461.0
#  Name: 425, dtype: float64, year
#  2020    1374.0
#  Name: 426, dtype: float64, year
#  2020    1898.0
#  Name: 427, dtype: float64, year
#  2020    1319.0
#  Name: 428, dtype: float64, year
#  2020    1939.0
#  Name: 429, dtype: float64, year
#  2020    1370.0
#  Name: 430, dtype: float64, year
#  2020    1858.0
#  Name: 431, dtype: float64, year
#  2020    1483.0
#  Name: 432, dtype: float64, year
#  2020    1333.0
#  Name: 433, dtype: float64, year
#  2020    2154.0
#  Name: 434, dtype: float64, year
#  2020    1628.0
#  Name: 435, dtype: float64, year
#  2020    1148.0
#  Name: 436, dtype: float64, year
#  2020    806.0
#  Name: 437, dtype: float64, year
#  2020    3440.0
#  Name: 438, dtype: float64, year
#  2020    1477.0
#  Name: 439, dtype: float64, year
#  2020    1904.0
#  Name: 440, dtype: float64, year
#  2020    1952.0
#  Name: 441, dtype: float64, year
#  2020    1672.0
#  Name: 442, dtype: float64, year
#  2020    1328.0
#  Name: 443, dtype: float64, year
#  2020    2640.0
#  Name: 444, dtype: float64, year
#  2020    1493.0
#  Name: 445, dtype: float64, year
#  2020    1713.0
#  Name: 446, dtype: float64, year
#  2020    1682.0
#  Name: 447, dtype: float64, year
#  2020    2280.0
#  Name: 448, dtype: float64, year
#  2020    778.0
#  Name: 449, dtype: float64, year
#  2020    2076.0
#  Name: 450, dtype: float64, year
#  2020    3238.0
#  Name: 451, dtype: float64, year
#  2020    1731.0
#  Name: 452, dtype: float64, year
#  2020    1485.0
#  Name: 453, dtype: float64, year
#  2020    1602.0
#  Name: 454, dtype: float64, year
#  2020    2160.0
#  Name: 455, dtype: float64, year
#  2020    1385.0
#  Name: 456, dtype: float64, year
#  2020    1352.0
#  Name: 457, dtype: float64, year
#  2020    1505.0
#  Name: 458, dtype: float64, year
#  2020    1286.0
#  Name: 459, dtype: float64, year
#  2020    2002.0
#  Name: 460, dtype: float64, year
#  2020    1305.0
#  Name: 461, dtype: float64, year
#  2020    1194.0
#  Name: 462, dtype: float64, year
#  2020    1797.0
#  Name: 463, dtype: float64, year
#  2020    1527.0
#  Name: 464, dtype: float64, year
#  2020    1914.0
#  Name: 465, dtype: float64, year
#  2020    1632.0
#  Name: 466, dtype: float64, year
#  2020    3941.0
#  Name: 467, dtype: float64, year
#  2020    1695.0
#  Name: 468, dtype: float64, year
#  2020    1129.0
#  Name: 469, dtype: float64, year
#  2020    1304.0
#  Name: 470, dtype: float64, year
#  2020    1508.0
#  Name: 471, dtype: float64, year
#  2020    1297.0
#  Name: 472, dtype: float64, year
#  2020    1414.0
#  Name: 473, dtype: float64, year
#  2020    1469.0
#  Name: 474, dtype: float64, year
#  2020    1545.0
#  Name: 475, dtype: float64, year
#  2020    1882.0
#  Name: 476, dtype: float64, year
#  2020    1280.0
#  Name: 477, dtype: float64, year
#  2020    1297.0
#  Name: 478, dtype: float64, year
#  2021    1270.0
#  Name: 479, dtype: float64, year
#  2021    1436.0
#  Name: 480, dtype: float64, year
#  2021    1650.0
#  Name: 481, dtype: float64, year
#  2021    1577.0
#  Name: 482, dtype: float64, year
#  2021    1499.0
#  Name: 483, dtype: float64, year
#  2021    1468.0
#  Name: 484, dtype: float64, year
#  2021    1439.0
#  Name: 485, dtype: float64, year
#  2021    1302.0
#  Name: 486, dtype: float64, year
#  2021    1340.0
#  Name: 487, dtype: float64, year
#  2021    1383.0
#  Name: 488, dtype: float64, year
#  2021    2023.0
#  Name: 489, dtype: float64, year
#  2021    1968.0
#  Name: 490, dtype: float64, year
#  2021    1251.0
#  Name: 491, dtype: float64, year
#  2021    2392.0
#  Name: 492, dtype: float64, year
#  2021    1686.0
#  Name: 493, dtype: float64, year
#  2021    1112.0
#  Name: 494, dtype: float64, year
#  2021    1767.0
#  Name: 495, dtype: float64, year
#  2021    2264.0
#  Name: 496, dtype: float64, year
#  2021    2412.0
#  Name: 497, dtype: float64, year
#  2021    1576.0
#  Name: 498, dtype: float64, year
#  2021    1973.0
#  Name: 499, dtype: float64, year
#  2021    1475.0
#  Name: 500, dtype: float64, year
#  2021    2019.0
#  Name: 501, dtype: float64, year
#  2021    1923.0
#  Name: 502, dtype: float64, year
#  2021    2940.0
#  Name: 503, dtype: float64, year
#  2021    1901.0
#  Name: 504, dtype: float64, year
#  2021    1890.0
#  Name: 505, dtype: float64, year
#  2021    2046.0
#  Name: 506, dtype: float64, year
#  2021    1149.0
#  Name: 507, dtype: float64, year
#  2021    2712.0
#  Name: 508, dtype: float64, year
#  2021    1845.0
#  Name: 509, dtype: float64, year
#  2021    1625.0
#  Name: 510, dtype: float64, year
#  2021    2060.0
#  Name: 511, dtype: float64, year
#  2021    1331.0
#  Name: 512, dtype: float64, year
#  2021    1601.0
#  Name: 513, dtype: float64, year
#  2021    2793.0
#  Name: 514, dtype: float64, year
#  2021    1477.0
#  Name: 515, dtype: float64, year
#  2021    1615.0
#  Name: 516, dtype: float64, year
#  2021    1637.0
#  Name: 517, dtype: float64, year
#  2021    1548.0
#  Name: 518, dtype: float64, year
#  2021    2011.0
#  Name: 519, dtype: float64, year
#  2021    1477.0
#  Name: 520, dtype: float64, year
#  2021    1328.0
#  Name: 521, dtype: float64, year
#  2021    1327.0
#  Name: 522, dtype: float64, year
#  2021    1723.0
#  Name: 523, dtype: float64, year
#  2021    1909.0
#  Name: 524, dtype: float64, year
#  2021    3544.0
#  Name: 525, dtype: float64, year
#  2021    1480.0
#  Name: 526, dtype: float64, year
#  2021    1399.0
#  Name: 527, dtype: float64, year
#  2021    1887.0
#  Name: 528, dtype: float64, year
#  2021    1909.0
#  Name: 529, dtype: float64, year
#  2021    3274.0
#  Name: 530, dtype: float64, year
#  2021    1077.0
#  Name: 531, dtype: float64, year
#  2021    1584.0
#  Name: 532, dtype: float64, year
#  2021    1736.0
#  Name: 533, dtype: float64, year
#  2021    1397.0
#  Name: 534, dtype: float64, year
#  2021    1710.0
#  Name: 535, dtype: float64, year
#  2021    1966.0
#  Name: 536, dtype: float64, year
#  2021    1238.0
#  Name: 537, dtype: float64, year
#  2021    1743.0
#  Name: 538, dtype: float64, year
#  2021    1609.0
#  Name: 539, dtype: float64, year
#  2021    1456.0
#  Name: 540, dtype: float64, year
#  2021    2078.0
#  Name: 541, dtype: float64, year
#  2021    1758.0
#  Name: 542, dtype: float64, year
#  2021    1983.0
#  Name: 543, dtype: float64, year
#  2021    1709.0
#  Name: 544, dtype: float64, year
#  2021    1229.0
#  Name: 545, dtype: float64, year
#  2021    3408.0
#  Name: 546, dtype: float64, year
#  2022    1586.0
#  Name: 547, dtype: float64, year
#  2022    1713.0
#  Name: 548, dtype: float64, year
#  2022    2060.0
#  Name: 549, dtype: float64, year
#  2022    1615.0
#  Name: 550, dtype: float64, year
#  2022    2507.0
#  Name: 551, dtype: float64, year
#  2022    1642.0
#  Name: 552, dtype: float64, year
#  2022    2046.0
#  Name: 553, dtype: float64, year
#  2022    1718.0
#  Name: 554, dtype: float64, year
#  2022    1826.0
#  Name: 555, dtype: float64, year
#  2022    2076.0
#  Name: 556, dtype: float64, year
#  2022    1623.0
#  Name: 557, dtype: float64, year
#  2022    2003.0
#  Name: 558, dtype: float64, year
#  2022    1907.0
#  Name: 559, dtype: float64, year
#  2022    1752.0
#  Name: 560, dtype: float64, year
#  2022    1921.0
#  Name: 561, dtype: float64, year
#  2022    1663.0
#  Name: 562, dtype: float64, year
#  2022    2211.0
#  Name: 563, dtype: float64, year
#  2022    1736.0
#  Name: 564, dtype: float64, year
#  2014    1579.0
#  Name: 565, dtype: float64, year
#  2014    1667.0
#  Name: 566, dtype: float64, year
#  2014    1223.0
#  Name: 567, dtype: float64, year
#  2014    1159.0
#  Name: 568, dtype: float64, year
#  2014    1091.0
#  Name: 569, dtype: float64, year
#  2014    1142.0
#  Name: 570, dtype: float64, year
#  2014    1162.0
#  Name: 571, dtype: float64, year
#  2014    993.0
#  Name: 572, dtype: float64, year
#  2014    2068.0
#  Name: 573, dtype: float64, year
#  2014    1286.0
#  Name: 574, dtype: float64, year
#  2014    1811.0
#  Name: 575, dtype: float64, year
#  2014    1225.0
#  Name: 576, dtype: float64, year
#  2014    1509.0
#  Name: 577, dtype: float64, year
#  2014    848.0
#  Name: 578, dtype: float64, year
#  2014    1173.0
#  Name: 579, dtype: float64, year
#  2014    1287.0
#  Name: 580, dtype: float64, year
#  2014    1906.0
#  Name: 581, dtype: float64, year
#  2014    1588.0
#  Name: 582, dtype: float64, year
#  2014    1587.0
#  Name: 583, dtype: float64, year
#  2014    1085.0
#  Name: 584, dtype: float64, year
#  2014    1011.0
#  Name: 585, dtype: float64, year
#  2014    1334.0
#  Name: 586, dtype: float64, year
#  2014    991.0
#  Name: 587, dtype: float64, year
#  2014    1013.0
#  Name: 588, dtype: float64, year
#  2014    1397.0
#  Name: 589, dtype: float64, year
#  2014    2630.0
#  Name: 590, dtype: float64, year
#  2014    1007.0
#  Name: 591, dtype: float64, year
#  2014    1218.0
#  Name: 592, dtype: float64, year
#  2014    977.0
#  Name: 593, dtype: float64, year
#  2014    1692.0
#  Name: 594, dtype: float64, year
#  2014    1433.0
#  Name: 595, dtype: float64, year
#  2014    837.0
#  Name: 596, dtype: float64, year
#  2014    939.0
#  Name: 597, dtype: float64, year
#  2014    1036.0
#  Name: 598, dtype: float64, year
#  2014    1272.0
#  Name: 599, dtype: float64, year
#  2014    1293.0
#  Name: 600, dtype: float64, year
#  2014    1521.0
#  Name: 601, dtype: float64, year
#  2014    1427.0
#  Name: 602, dtype: float64, year
#  2014    1267.0
#  Name: 603, dtype: float64, year
#  2014    786.0
#  Name: 604, dtype: float64, year
#  2014    1250.0
#  Name: 605, dtype: float64, year
#  2014    917.0
#  Name: 606, dtype: float64, year
#  2014    1311.0
#  Name: 607, dtype: float64, year
#  2014    1897.0
#  Name: 608, dtype: float64, year
#  2014    2060.0
#  Name: 609, dtype: float64, year
#  2014    1906.0
#  Name: 610, dtype: float64, year
#  2014    1038.0
#  Name: 611, dtype: float64, year
#  2014    1147.0
#  Name: 612, dtype: float64, year
#  2014    1447.0
#  Name: 613, dtype: float64, year
#  2014    1122.0
#  Name: 614, dtype: float64, year
#  2014    2229.0
#  Name: 615, dtype: float64, year
#  2014    1269.0
#  Name: 616, dtype: float64, year
#  2014    1462.0
#  Name: 617, dtype: float64, year
#  2014    1302.0
#  Name: 618, dtype: float64, year
#  2014    2035.0
#  Name: 619, dtype: float64, year
#  2014    1046.0
#  Name: 620, dtype: float64, year
#  2014    1128.0
#  Name: 621, dtype: float64, year
#  2014    2008.0
#  Name: 622, dtype: float64, year
#  2014    1134.0
#  Name: 623, dtype: float64, year
#  2014    2244.0
#  Name: 624, dtype: float64, year
#  2014    2109.0
#  Name: 625, dtype: float64, year
#  2014    686.0
#  Name: 626, dtype: float64, year
#  2014    621.0
#  Name: 627, dtype: float64, year
#  2015    1907.0
#  Name: 628, dtype: float64, year
#  2015    921.0
#  Name: 629, dtype: float64, year
#  2015    1119.0
#  Name: 630, dtype: float64, year
#  2015    1142.0
#  Name: 631, dtype: float64, year
#  2015    1826.0
#  Name: 632, dtype: float64, year
#  2015    1453.0
#  Name: 633, dtype: float64, year
#  2015    1397.0
#  Name: 634, dtype: float64, year
#  2015    1954.0
#  Name: 635, dtype: float64, year
#  2015    1018.0
#  Name: 636, dtype: float64, year
#  2015    1821.0
#  Name: 637, dtype: float64, year
#  2015    1151.0
#  Name: 638, dtype: float64, year
#  2015    1995.0
#  Name: 639, dtype: float64, year
#  2015    975.0
#  Name: 640, dtype: float64, year
#  2015    1145.0
#  Name: 641, dtype: float64, year
#  2015    1993.0
#  Name: 642, dtype: float64, year
#  2015    1567.0
#  Name: 643, dtype: float64, year
#  2015    1341.0
#  Name: 644, dtype: float64, year
#  2015    954.0
#  Name: 645, dtype: float64, year
#  2015    1967.0
#  Name: 646, dtype: float64, year
#  2015    1472.0
#  Name: 647, dtype: float64, year
#  2015    876.0
#  Name: 648, dtype: float64, year
#  2015    2665.0
#  Name: 649, dtype: float64, year
#  2015    1626.0
#  Name: 650, dtype: float64, year
#  2015    2938.0
#  Name: 651, dtype: float64, year
#  2015    1500.0
#  Name: 652, dtype: float64, year
#  2015    1309.0
#  Name: 653, dtype: float64, year
#  2015    1010.0
#  Name: 654, dtype: float64, year
#  2015    1483.0
#  Name: 655, dtype: float64, year
#  2015    4591.0
#  Name: 656, dtype: float64, year
#  2015    886.0
#  Name: 657, dtype: float64, year
#  2015    1609.0
#  Name: 658, dtype: float64, year
#  2015    1414.0
#  Name: 659, dtype: float64, year
#  2015    2852.0
#  Name: 660, dtype: float64, year
#  2015    2004.0
#  Name: 661, dtype: float64, year
#  2015    954.0
#  Name: 662, dtype: float64, year
#  2015    2895.0
#  Name: 663, dtype: float64, year
#  2015    1002.0
#  Name: 664, dtype: float64, year
#  2015    2302.0
#  Name: 665, dtype: float64, year
#  2015    1291.0
#  Name: 666, dtype: float64, year
#  2015    1051.0
#  Name: 667, dtype: float64, year
#  2015    1523.0
#  Name: 668, dtype: float64, year
#  2015    2150.0
#  Name: 669, dtype: float64, year
#  2015    1263.0
#  Name: 670, dtype: float64, year
#  2015    2012.0
#  Name: 671, dtype: float64, year
#  2015    1439.0
#  Name: 672, dtype: float64, year
#  2015    2688.0
#  Name: 673, dtype: float64, year
#  2015    923.0
#  Name: 674, dtype: float64, year
#  2015    1058.0
#  Name: 675, dtype: float64, year
#  2015    6076.0
#  Name: 676, dtype: float64, year
#  2015    1599.0
#  Name: 677, dtype: float64, year
#  2015    676.0
#  Name: 678, dtype: float64, year
#  2015    1115.0
#  Name: 679, dtype: float64, year
#  2015    1782.0
#  Name: 680, dtype: float64, year
#  2015    2235.0
#  Name: 681, dtype: float64, year
#  2015    1797.0
#  Name: 682, dtype: float64, year
#  2015    1872.0
#  Name: 683, dtype: float64, year
#  2015    1102.0
#  Name: 684, dtype: float64, year
#  2015    1347.0
#  Name: 685, dtype: float64, year
#  2015    951.0
#  Name: 686, dtype: float64, year
#  2015    1169.0
#  Name: 687, dtype: float64, year
#  2015    1572.0
#  Name: 688, dtype: float64, year
#  2015    924.0
#  Name: 689, dtype: float64, year
#  2015    1366.0
#  Name: 690, dtype: float64, year
#  2015    1043.0
#  Name: 691, dtype: float64, year
#  2015    986.0
#  Name: 692, dtype: float64, year
#  2015    1078.0
#  Name: 693, dtype: float64, year
#  2015    1715.0
#  Name: 694, dtype: float64, year
#  2016    1266.0
#  Name: 695, dtype: float64, year
#  2016    1334.0
#  Name: 696, dtype: float64, year
#  2016    1928.0
#  Name: 697, dtype: float64, year
#  2016    1635.0
#  Name: 698, dtype: float64, year
#  2016    1448.0
#  Name: 699, dtype: float64, year
#  2016    1298.0
#  Name: 700, dtype: float64, year
#  2016    2368.0
#  Name: 701, dtype: float64, year
#  2016    878.0
#  Name: 702, dtype: float64, year
#  2016    1791.0
#  Name: 703, dtype: float64, year
#  2016    1083.0
#  Name: 704, dtype: float64, year
#  2016    1615.0
#  Name: 705, dtype: float64, year
#  2016    1380.0
#  Name: 706, dtype: float64, year
#  2016    873.0
#  Name: 707, dtype: float64, year
#  2016    1721.0
#  Name: 708, dtype: float64, year
#  2016    1441.0
#  Name: 709, dtype: float64, year
#  2016    3307.0
#  Name: 710, dtype: float64, year
#  2016    1457.0
#  Name: 711, dtype: float64, year
#  2016    2009.0
#  Name: 712, dtype: float64, year
#  2016    1283.0
#  Name: 713, dtype: float64, year
#  2016    1245.0
#  Name: 714, dtype: float64, year
#  2016    2733.0
#  Name: 715, dtype: float64, year
#  2016    1751.0
#  Name: 716, dtype: float64, year
#  2016    3183.0
#  Name: 717, dtype: float64, year
#  2016    2581.0
#  Name: 718, dtype: float64, year
#  2016    1498.0
#  Name: 719, dtype: float64, year
#  2016    1299.0
#  Name: 720, dtype: float64, year
#  2016    1279.0
#  Name: 721, dtype: float64, year
#  2016    1128.0
#  Name: 722, dtype: float64, year
#  2016    1346.0
#  Name: 723, dtype: float64, year
#  2016    1233.0
#  Name: 724, dtype: float64, year
#  2016    1529.0
#  Name: 725, dtype: float64, year
#  2016    1161.0
#  Name: 726, dtype: float64, year
#  2016    1634.0
#  Name: 727, dtype: float64, year
#  2016    2506.0
#  Name: 728, dtype: float64, year
#  2016    1544.0
#  Name: 729, dtype: float64, year
#  2016    2088.0
#  Name: 730, dtype: float64, year
#  2016    1134.0
#  Name: 731, dtype: float64, year
#  2016    1093.0
#  Name: 732, dtype: float64, year
#  2016    937.0
#  Name: 733, dtype: float64, year
#  2016    1090.0
#  Name: 734, dtype: float64, year
#  2016    1628.0
#  Name: 735, dtype: float64, year
#  2016    2364.0
#  Name: 736, dtype: float64, year
#  2016    1241.0
#  Name: 737, dtype: float64, year
#  2016    1200.0
#  Name: 738, dtype: float64, year
#  2016    720.0
#  Name: 739, dtype: float64, year
#  2016    1282.0
#  Name: 740, dtype: float64, year
#  2016    1031.0
#  Name: 741, dtype: float64, year
#  2016    1828.0
#  Name: 742, dtype: float64, year
#  2016    2131.0
#  Name: 743, dtype: float64, year
#  2016    887.0
#  Name: 744, dtype: float64, year
#  2016    1375.0
#  Name: 745, dtype: float64, year
#  2016    3104.0
#  Name: 746, dtype: float64, year
#  2016    1196.0
#  Name: 747, dtype: float64, year
#  2016    1766.0
#  Name: 748, dtype: float64, year
#  2016    1430.0
#  Name: 749, dtype: float64, year
#  2016    2828.0
#  Name: 750, dtype: float64, year
#  2016    1826.0
#  Name: 751, dtype: float64, year
#  2016    1633.0
#  Name: 752, dtype: float64, year
#  2016    840.0
#  Name: 753, dtype: float64, year
#  2016    1354.0
#  Name: 754, dtype: float64, year
#  2016    1243.0
#  Name: 755, dtype: float64, year
#  2016    2679.0
#  Name: 756, dtype: float64, year
#  2016    871.0
#  Name: 757, dtype: float64, year
#  2016    1455.0
#  Name: 758, dtype: float64, year
#  2016    996.0
#  Name: 759, dtype: float64, year
#  2016    1952.0
#  Name: 760, dtype: float64, year
#  2016    1081.0
#  Name: 761, dtype: float64, year
#  2016    1365.0
#  Name: 762, dtype: float64, year
#  2016    1433.0
#  Name: 763, dtype: float64, year
#  2016    1195.0
#  Name: 764, dtype: float64, year
#  2016    1427.0
#  Name: 765, dtype: float64, year
#  2016    1088.0
#  Name: 766, dtype: float64, year
#  2017    1929.0
#  Name: 767, dtype: float64, year
#  2017    2677.0
#  Name: 768, dtype: float64, year
#  2017    2462.0
#  Name: 769, dtype: float64, year
#  2017    1425.0
#  Name: 770, dtype: float64, year
#  2017    1249.0
#  Name: 771, dtype: float64, year
#  2017    1801.0
#  Name: 772, dtype: float64, year
#  2017    2089.0
#  Name: 773, dtype: float64, year
#  2017    1134.0
#  Name: 774, dtype: float64, year
#  2017    1257.0
#  Name: 775, dtype: float64, year
#  2017    3385.0
#  Name: 776, dtype: float64, year
#  2017    2476.0
#  Name: 777, dtype: float64, year
#  2017    1329.0
#  Name: 778, dtype: float64, year
#  2017    1578.0
#  Name: 779, dtype: float64, year
#  2017    2148.0
#  Name: 780, dtype: float64, year
#  2017    2231.0
#  Name: 781, dtype: float64, year
#  2017    1415.0
#  Name: 782, dtype: float64, year
#  2017    1811.0
#  Name: 783, dtype: float64, year
#  2017    2432.0
#  Name: 784, dtype: float64, year
#  2017    1410.0
#  Name: 785, dtype: float64, year
#  2017    907.0
#  Name: 786, dtype: float64, year
#  2017    1166.0
#  Name: 787, dtype: float64, year
#  2017    2314.0
#  Name: 788, dtype: float64, year
#  2017    1290.0
#  Name: 789, dtype: float64, year
#  2017    3032.0
#  Name: 790, dtype: float64, year
#  2017    2094.0
#  Name: 791, dtype: float64, year
#  2017    1465.0
#  Name: 792, dtype: float64, year
#  2017    2748.0
#  Name: 793, dtype: float64, year
#  2017    1191.0
#  Name: 794, dtype: float64, year
#  2017    771.0
#  Name: 795, dtype: float64, year
#  2017    1843.0
#  Name: 796, dtype: float64, year
#  2017    1086.0
#  Name: 797, dtype: float64, year
#  2017    1258.0
#  Name: 798, dtype: float64, year
#  2017    878.0
#  Name: 799, dtype: float64, year
#  2017    1275.0
#  Name: 800, dtype: float64, year
#  2017    1714.0
#  Name: 801, dtype: float64, year
#  2017    938.0
#  Name: 802, dtype: float64, year
#  2017    618.0
#  Name: 803, dtype: float64, year
#  2017    2458.0
#  Name: 804, dtype: float64, year
#  2017    1606.0
#  Name: 805, dtype: float64, year
#  2017    1083.0
#  Name: 806, dtype: float64, year
#  2017    1509.0
#  Name: 807, dtype: float64, year
#  2017    1107.0
#  Name: 808, dtype: float64, year
#  2017    1292.0
#  Name: 809, dtype: float64, year
#  2017    1887.0
#  Name: 810, dtype: float64, year
#  2017    2064.0
#  Name: 811, dtype: float64, year
#  2017    1469.0
#  Name: 812, dtype: float64, year
#  2017    1257.0
#  Name: 813, dtype: float64, year
#  2017    1138.0
#  Name: 814, dtype: float64, year
#  2017    1916.0
#  Name: 815, dtype: float64, year
#  2017    1242.0
#  Name: 816, dtype: float64, year
#  2017    2228.0
#  Name: 817, dtype: float64, year
#  2017    1337.0
#  Name: 818, dtype: float64, year
#  2017    1836.0
#  Name: 819, dtype: float64, year
#  2017    1281.0
#  Name: 820, dtype: float64, year
#  2017    1086.0
#  Name: 821, dtype: float64, year
#  2017    1333.0
#  Name: 822, dtype: float64, year
#  2017    1509.0
#  Name: 823, dtype: float64, year
#  2017    1227.0
#  Name: 824, dtype: float64, year
#  2017    2364.0
#  Name: 825, dtype: float64, year
#  2017    1844.0
#  Name: 826, dtype: float64, year
#  2017    1677.0
#  Name: 827, dtype: float64, year
#  2017    1214.0
#  Name: 828, dtype: float64, year
#  2017    1255.0
#  Name: 829, dtype: float64, year
#  2017    1399.0
#  Name: 830, dtype: float64, year
#  2017    1271.0
#  Name: 831, dtype: float64, year
#  2017    2040.0
#  Name: 832, dtype: float64, year
#  2017    1462.0
#  Name: 833, dtype: float64, year
#  2017    1157.0
#  Name: 834, dtype: float64, year
#  2017    1558.0
#  Name: 835, dtype: float64, year
#  2017    1381.0
#  Name: 836, dtype: float64, year
#  2017    1482.0
#  Name: 837, dtype: float64, year
#  2017    1015.0
#  Name: 838, dtype: float64, year
#  2017    1651.0
#  Name: 839, dtype: float64, year
#  2017    770.0
#  Name: 840, dtype: float64, year
#  2017    2967.0
#  Name: 841, dtype: float64, year
#  2017    1214.0
#  Name: 842, dtype: float64, year
#  2017    1475.0
#  Name: 843, dtype: float64, year
#  2017    1275.0
#  Name: 844, dtype: float64, year
#  2017    1843.0
#  Name: 845, dtype: float64, year
#  2017    883.0
#  Name: 846, dtype: float64, year
#  2017    2077.0
#  Name: 847, dtype: float64, year
#  2017    1081.0
#  Name: 848, dtype: float64, year
#  2017    3354.0
#  Name: 849, dtype: float64, year
#  2017    5277.0
#  Name: 850, dtype: float64, year
#  2018    2215.0
#  Name: 851, dtype: float64, year
#  2018    1892.0
#  Name: 852, dtype: float64, year
#  2018    1391.0
#  Name: 853, dtype: float64, year
#  2018    1131.0
#  Name: 854, dtype: float64, year
#  2018    1144.0
#  Name: 855, dtype: float64, year
#  2018    1623.0
#  Name: 856, dtype: float64, year
#  2018    1254.0
#  Name: 857, dtype: float64, year
#  2018    911.0
#  Name: 858, dtype: float64, year
#  2018    1240.0
#  Name: 859, dtype: float64, year
#  2018    2305.0
#  Name: 860, dtype: float64, year
#  2018    1417.0
#  Name: 861, dtype: float64, year
#  2018    1333.0
#  Name: 862, dtype: float64, year
#  2018    1552.0
#  Name: 863, dtype: float64, year
#  2018    1619.0
#  Name: 864, dtype: float64, year
#  2018    1452.0
#  Name: 865, dtype: float64, year
#  2018    1542.0
#  Name: 866, dtype: float64, year
#  2018    1597.0
#  Name: 867, dtype: float64, year
#  2018    1220.0
#  Name: 868, dtype: float64, year
#  2018    970.0
#  Name: 869, dtype: float64, year
#  2018    748.0
#  Name: 870, dtype: float64, year
#  2018    802.0
#  Name: 871, dtype: float64, year
#  2018    828.0
#  Name: 872, dtype: float64, year
#  2018    1450.0
#  Name: 873, dtype: float64, year
#  2018    853.0
#  Name: 874, dtype: float64, year
#  2018    3220.0
#  Name: 875, dtype: float64, year
#  2018    3395.0
#  Name: 876, dtype: float64, year
#  2018    2525.0
#  Name: 877, dtype: float64, year
#  2018    1767.0
#  Name: 878, dtype: float64, year
#  2018    1710.0
#  Name: 879, dtype: float64, year
#  2018    1032.0
#  Name: 880, dtype: float64, year
#  2018    1380.0
#  Name: 881, dtype: float64, year
#  2018    1109.0
#  Name: 882, dtype: float64, year
#  2018    1960.0
#  Name: 883, dtype: float64, year
#  2018    5615.0
#  Name: 884, dtype: float64, year
#  2018    1171.0
#  Name: 885, dtype: float64, year
#  2018    2401.0
#  Name: 886, dtype: float64, year
#  2018    872.0
#  Name: 887, dtype: float64, year
#  2018    1474.0
#  Name: 888, dtype: float64, year
#  2018    1197.0
#  Name: 889, dtype: float64, year
#  2018    1100.0
#  Name: 890, dtype: float64, year
#  2018    1399.0
#  Name: 891, dtype: float64, year
#  2018    1727.0
#  Name: 892, dtype: float64, year
#  2018    1173.0
#  Name: 893, dtype: float64, year
#  2018    2462.0
#  Name: 894, dtype: float64, year
#  2018    2302.0
#  Name: 895, dtype: float64, year
#  2018    1199.0
#  Name: 896, dtype: float64, year
#  2018    1859.0
#  Name: 897, dtype: float64, year
#  2018    1235.0
#  Name: 898, dtype: float64, year
#  2018    1193.0
#  Name: 899, dtype: float64, year
#  2018    1383.0
#  Name: 900, dtype: float64, year
#  2018    1352.0
#  Name: 901, dtype: float64, year
#  2018    682.0
#  Name: 902, dtype: float64, year
#  2018    1160.0
#  Name: 903, dtype: float64, year
#  2018    801.0
#  Name: 904, dtype: float64, year
#  2018    688.0
#  Name: 905, dtype: float64, year
#  2018    2304.0
#  Name: 906, dtype: float64, year
#  2018    1393.0
#  Name: 907, dtype: float64, year
#  2018    1278.0
#  Name: 908, dtype: float64, year
#  2018    1463.0
#  Name: 909, dtype: float64, year
#  2018    1262.0
#  Name: 910, dtype: float64, year
#  2018    1173.0
#  Name: 911, dtype: float64, year
#  2018    3526.0
#  Name: 912, dtype: float64, year
#  2018    1121.0
#  Name: 913, dtype: float64, year
#  2018    1483.0
#  Name: 914, dtype: float64, year
#  2018    2376.0
#  Name: 915, dtype: float64, year
#  2018    1261.0
#  Name: 916, dtype: float64, year
#  2018    1531.0
#  Name: 917, dtype: float64, year
#  2018    1754.0
#  Name: 918, dtype: float64, year
#  2018    1554.0
#  Name: 919, dtype: float64, year
#  2018    1026.0
#  Name: 920, dtype: float64, year
#  2018    1781.0
#  Name: 921, dtype: float64, year
#  2018    4993.0
#  Name: 922, dtype: float64, year
#  2018    1457.0
#  Name: 923, dtype: float64, year
#  2018    1533.0
#  Name: 924, dtype: float64, year
#  2018    1752.0
#  Name: 925, dtype: float64, year
#  2018    2798.0
#  Name: 926, dtype: float64, year
#  2018    1110.0
#  Name: 927, dtype: float64, year
#  2018    1172.0
#  Name: 928, dtype: float64, year
#  2018    1409.0
#  Name: 929, dtype: float64, year
#  2018    2329.0
#  Name: 930, dtype: float64, year
#  2018    1580.0
#  Name: 931, dtype: float64, year
#  2018    1086.0
#  Name: 932, dtype: float64, year
#  2018    2070.0
#  Name: 933, dtype: float64, year
#  2018    2004.0
#  Name: 934, dtype: float64, year
#  2018    1974.0
#  Name: 935, dtype: float64, year
#  2018    1505.0
#  Name: 936, dtype: float64, year
#  2018    1944.0
#  Name: 937, dtype: float64, year
#  2018    1512.0
#  Name: 938, dtype: float64, year
#  2018    1760.0
#  Name: 939, dtype: float64, year
#  2018    1379.0
#  Name: 940, dtype: float64, year
#  2018    1262.0
#  Name: 941, dtype: float64, year
#  2018    1430.0
#  Name: 942, dtype: float64, year
#  2018    1072.0
#  Name: 943, dtype: float64, year
#  2018    1382.0
#  Name: 944, dtype: float64, year
#  2018    1164.0
#  Name: 945, dtype: float64, year
#  2018    1123.0
#  Name: 946, dtype: float64, year
#  2018    1269.0
#  Name: 947, dtype: float64, year
#  2018    1713.0
#  Name: 948, dtype: float64, year
#  2018    1079.0
#  Name: 949, dtype: float64, year
#  2018    1992.0
#  Name: 950, dtype: float64, year
#  2018    2679.0
#  Name: 951, dtype: float64, year
#  2018    1290.0
#  Name: 952, dtype: float64, year
#  2019    1496.0
#  Name: 953, dtype: float64, year
#  2019    1080.0
#  Name: 954, dtype: float64, year
#  2019    1542.0
#  Name: 955, dtype: float64, year
#  2019    1296.0
#  Name: 956, dtype: float64, year
#  2019    1663.0
#  Name: 957, dtype: float64, year
#  2019    1276.0
#  Name: 958, dtype: float64, year
#  2019    1973.0
#  Name: 959, dtype: float64, year
#  2019    1312.0
#  Name: 960, dtype: float64, year
#  2019    1857.0
#  Name: 961, dtype: float64, year
#  2019    1577.0
#  Name: 962, dtype: float64, year
#  2019    1655.0
#  Name: 963, dtype: float64, year
#  2019    1273.0
#  Name: 964, dtype: float64, year
#  2019    1651.0
#  Name: 965, dtype: float64, year
#  2019    1118.0
#  Name: 966, dtype: float64, year
#  2019    1680.0
#  Name: 967, dtype: float64, year
#  2019    1783.0
#  Name: 968, dtype: float64, year
#  2019    1062.0
#  Name: 969, dtype: float64, year
#  2019    1728.0
#  Name: 970, dtype: float64, year
#  2019    1679.0
#  Name: 971, dtype: float64, year
#  2019    2050.0
#  Name: 972, dtype: float64, year
#  2019    1034.0
#  Name: 973, dtype: float64, year
#  2019    1234.0
#  Name: 974, dtype: float64, year
#  2019    1566.0
#  Name: 975, dtype: float64, year
#  2019    1386.0
#  Name: 976, dtype: float64, year
#  2019    3771.0
#  Name: 977, dtype: float64, year
#  2019    1600.0
#  Name: 978, dtype: float64, year
#  2019    1137.0
#  Name: 979, dtype: float64, year
#  2019    1769.0
#  Name: 980, dtype: float64, year
#  2019    1322.0
#  Name: 981, dtype: float64, year
#  2019    1262.0
#  Name: 982, dtype: float64, year
#  2019    1120.0
#  Name: 983, dtype: float64, year
#  2019    1412.0
#  Name: 984, dtype: float64, year
#  2019    1135.0
#  Name: 985, dtype: float64, year
#  2019    1272.0
#  Name: 986, dtype: float64, year
#  2019    1446.0
#  Name: 987, dtype: float64, year
#  2019    2710.0
#  Name: 988, dtype: float64, year
#  2019    2484.0
#  Name: 989, dtype: float64, year
#  2019    2717.0
#  Name: 990, dtype: float64, year
#  2019    2292.0
#  Name: 991, dtype: float64, year
#  2019    1415.0
#  Name: 992, dtype: float64, year
#  2019    2278.0
#  Name: 993, dtype: float64, year
#  2019    1154.0
#  Name: 994, dtype: float64, year
#  2019    1442.0
#  Name: 995, dtype: float64, year
#  2019    1173.0
#  Name: 996, dtype: float64, year
#  2019    1482.0
#  Name: 997, dtype: float64, year
#  2019    2146.0
#  Name: 998, dtype: float64, year
#  2019    2527.0
#  Name: 999, dtype: float64, ...]

# %%
import matplotlib.pyplot as plt

ax = box_df[[2014,2015,2016,2017,2018,2019,2020,2021,2022]].plot(kind='box', title='boxplot')
# plt.boxplot(box_df.year, box_df.rent)
plt.xlabel('rent')
plt.ylabel('year')
plt.show()

# %%
print(box_df)
# Out:
# [        zipcode    primarycity                     city        date    rent  \
# 0         91710          Chino            Riverside, CA  2014-01-01  1810.0
# 1         28078   Huntersville            Charlotte, NC  2014-01-01  1205.0
# 2         89074      Henderson            Las Vegas, NV  2014-01-01  1040.0
# 3         20910  Silver Spring           Washington, DC  2014-01-01  1830.0
# 4         55104     Saint Paul  Minneapolis-St Paul, MN  2014-01-01  1087.0
# ...         ...            ...                      ...         ...     ...
# 216393    21211      Baltimore            Baltimore, MD  2014-11-01  1310.0
# 216394    21076        Hanover            Baltimore, MD  2014-11-01  1882.0
# 216395    89128      Las Vegas            Las Vegas, NV  2014-12-01   948.0
# 216396    85302       Glendale              Phoenix, AZ  2014-12-01   804.0
# 216397    76119     Fort Worth    Dallas-Fort Worth, TX  2014-12-01   862.0
#
#         latitude  longitude                 county  year  month  homevalue
# 0          34.00    -117.68  San Bernardino County  2014      1   393085.0
# 1          35.41     -80.84     Mecklenburg County  2014      1   252566.0
# 2          36.03    -115.07           Clark County  2014      1   216309.0
# 3          39.00     -77.04      Montgomery County  2014      1   541022.0
# 4          44.95     -93.16          Ramsey County  2014      1   190597.0
# ...          ...        ...                    ...   ...    ...        ...
# 216393     39.33     -76.64         Baltimore city  2014     11   197157.0
# 216394     39.16     -76.72    Anne Arundel County  2014     11   384975.0
# 216395     36.19    -115.26           Clark County  2014     12   178405.0
# 216396     33.57    -112.18        Maricopa County  2014     12   148014.0
# 216397     32.69     -97.26         Tarrant County  2014     12    67115.0
#
# [24314 rows x 11 columns],         zipcode        primarycity              city        date    rent  \
# 60        60657            Chicago       Chicago, IL  2015-01-01  1447.0
# 61        60618            Chicago       Chicago, IL  2015-01-01  1301.0
# 62        27612            Raleigh       Raleigh, NC  2015-01-01  1002.0
# 63        89014          Henderson     Las Vegas, NV  2015-01-01   916.0
# 64        30060           Marietta       Atlanta, GA  2015-01-01   980.0
# ...         ...                ...               ...         ...     ...
# 216459    98023        Federal Way       Seattle, WA  2015-12-01  1321.0
# 216460    19130       Philadelphia  Philadelphia, PA  2015-12-01  1685.0
# 216461    95691    West Sacramento    Sacramento, CA  2015-12-01  1464.0
# 216462    60005  Arlington Heights       Chicago, IL  2015-12-01  1178.0
# 216463    33916         Fort Myers    Fort Myers, FL  2015-12-01   957.0
#
#         latitude  longitude               county  year  month  homevalue
# 60         41.94     -87.65          Cook County  2015      1   453761.0
# 61         41.95     -87.70          Cook County  2015      1   436618.0
# 62         35.85     -78.71          Wake County  2015      1   291246.0
# 63         36.05    -115.05         Clark County  2015      1   196666.0
# 64         33.95     -84.54          Cobb County  2015      1   142582.0
# ...          ...        ...                  ...   ...    ...        ...
# 216459     47.30    -122.37          King County  2015     12   304735.0
# 216460     39.97     -75.18  Philadelphia County  2015     12   337097.0
# 216461     38.66    -121.62          Yolo County  2015     12   337083.0
# 216462     42.06     -87.99          Cook County  2015     12   331952.0
# 216463     26.63     -81.85           Lee County  2015     12   105143.0
#
# [25841 rows x 11 columns],         zipcode  primarycity                                city        date  \
# 133       78109     Converse                     San Antonio, TX  2016-01-01
# 134        7960   Morristown                        New York, NY  2016-01-01
# 135       27560  Morrisville                         Raleigh, NC  2016-01-01
# 136       20002   Washington                      Washington, DC  2016-02-01
# 137       94565    Pittsburg                   San Francisco, CA  2016-02-01
# ...         ...          ...                                 ...         ...
# 216523    83704        Boise                      Boise City, ID  2016-12-01
# 216524    85021      Phoenix                         Phoenix, AZ  2016-12-01
# 216525     7307  Jersey City                        New York, NY  2016-12-01
# 216526    91321      Newhall  Los Angeles-Long Beach-Anaheim, CA  2016-12-01
# 216527    11542    Glen Cove                        New York, NY  2016-12-01
#
#           rent  latitude  longitude                county  year  month  \
# 133     1120.0     29.51     -98.31          Bexar County  2016      1
# 134     2260.0     40.79     -74.47         Morris County  2016      1
# 135     1339.0     35.83     -78.83           Wake County  2016      1
# 136     2011.0     38.91     -76.98  District of Columbia  2016      2
# 137     1612.0     38.01    -121.91   Contra Costa County  2016      2
# ...        ...       ...        ...                   ...   ...    ...
# 216523   939.0     43.63    -116.28            Ada County  2016     12
# 216524   826.0     33.55    -112.09       Maricopa County  2016     12
# 216525  1793.0     40.75     -74.06         Hudson County  2016     12
# 216526  1762.0     34.36    -118.47    Los Angeles County  2016     12
# 216527  2815.0     40.86     -73.63         Nassau County  2016     12
#
#         homevalue
# 133      155551.0
# 134      562341.0
# 135      281816.0
# 136      590889.0
# 137      504732.0
# ...           ...
# 216523   194070.0
# 216524   237015.0
# 216525   424213.0
# 216526   446368.0
# 216527   533117.0
#
# [26359 rows x 11 columns],         zipcode        primarycity                                city  \
# 188       98052            Redmond                         Seattle, WA
# 189       76248             Keller               Dallas-Fort Worth, TX
# 190       91316             Encino  Los Angeles-Long Beach-Anaheim, CA
# 191       92011           Carlsbad                       San Diego, CA
# 192       90272  Pacific Palisades  Los Angeles-Long Beach-Anaheim, CA
# ...         ...                ...                                 ...
# 216572    92336            Fontana                       Riverside, CA
# 216573    78250        San Antonio                     San Antonio, TX
# 216574    27518               Cary                         Raleigh, NC
# 216575    98108            Seattle                         Seattle, WA
# 216576    78747             Austin                          Austin, TX
#
#               date    rent  latitude  longitude                 county  year  \
# 188     2017-01-01  1883.0     47.68    -122.12            King County  2017
# 189     2017-01-01  1347.0     32.93     -97.22         Tarrant County  2017
# 190     2017-01-01  2403.0     34.15    -118.52     Los Angeles County  2017
# 191     2017-01-01  2545.0     33.10    -117.29       San Diego County  2017
# 192     2017-01-01  5005.0     34.07    -118.54     Los Angeles County  2017
# ...            ...     ...       ...        ...                    ...   ...
# 216572  2017-10-01  2212.0     34.14    -117.45  San Bernardino County  2017
# 216573  2017-10-01   945.0     29.50     -98.66           Bexar County  2017
# 216574  2017-10-01  1205.0     35.73     -78.77            Wake County  2017
# 216575  2017-11-01  1759.0     47.54    -122.31            King County  2017
# 216576  2017-11-01  1643.0     30.13     -97.74          Travis County  2017
#
#         month  homevalue
# 188         1   743634.0
# 189         1   373980.0
# 190         1   664686.0
# 191         1   873464.0
# 192         1  3027285.0
# ...       ...        ...
# 216572     10   431072.0
# 216573     10   167562.0
# 216574     10   420576.0
# 216575     11   547855.0
# 216576     11   258766.0
#
# [26740 rows x 11 columns],         zipcode      primarycity                                city  \
# 268       91801         Alhambra  Los Angeles-Long Beach-Anaheim, CA
# 269        7728         Freehold                        New York, NY
# 270       20850        Rockville                      Washington, DC
# 271       78250      San Antonio                     San Antonio, TX
# 272       33316  Fort Lauderdale           Miami-Fort Lauderdale, FL
# ...         ...              ...                                 ...
# 216603    93551         Palmdale  Los Angeles-Long Beach-Anaheim, CA
# 216604    77088          Houston                         Houston, TX
# 216605    93010        Camarillo                         Ventura, CA
# 216606    32818          Orlando                         Orlando, FL
# 216607    30252        Mcdonough                         Atlanta, GA
#
#               date    rent  latitude  longitude              county  year  \
# 268     2018-01-01  1996.0     34.09    -118.13  Los Angeles County  2018
# 269     2018-01-01  1855.0     40.25     -74.27     Monmouth County  2018
# 270     2018-01-01  1878.0     39.08     -77.15   Montgomery County  2018
# 271     2018-01-01   945.0     29.50     -98.66        Bexar County  2018
# 272     2018-01-01  1742.0     26.10     -80.12      Broward County  2018
# ...            ...     ...       ...        ...                 ...   ...
# 216603  2018-04-01  2094.0     34.61    -118.27  Los Angeles County  2018
# 216604  2018-04-01  1372.0     29.88     -95.45       Harris County  2018
# 216605  2018-04-01  2516.0     34.23    -119.07      Ventura County  2018
# 216606  2018-04-01  1321.0     28.59     -81.49       Orange County  2018
# 216607  2018-04-01  1381.0     33.47     -84.06        Henry County  2018
#
#         month  homevalue
# 268         1   638345.0
# 269         1   362028.0
# 270         1   566933.0
# 271         1   168874.0
# 272         1   529087.0
# ...       ...        ...
# 216603      4   398042.0
# 216604      4   134180.0
# 216605      4   629520.0
# 216606      4   200855.0
# 216607      4   222398.0
#
# [26825 rows x 11 columns],         zipcode    primarycity                                city  \
# 328        6902       Stamford                        Stamford, CT
# 329       22202      Arlington                      Washington, DC
# 330       38128        Memphis                         Memphis, TN
# 331       30813      Grovetown                         Augusta, GA
# 332       75033         Frisco               Dallas-Fort Worth, TX
# ...         ...            ...                                 ...
# 216187    91360  Thousand Oaks                         Ventura, CA
# 216188    23503        Norfolk                  Virginia Beach, VA
# 216189    91311     Chatsworth  Los Angeles-Long Beach-Anaheim, CA
# 216190    85298        Gilbert                         Phoenix, AZ
# 216191    94301      Palo Alto                        San Jose, CA
#
#               date    rent  latitude  longitude              county  year  \
# 328     2019-01-01  2335.0     41.06     -73.54    Fairfield County  2019
# 329     2019-01-01  2052.0     38.86     -77.05    Arlington County  2019
# 330     2019-01-01   995.0     35.22     -89.93       Shelby County  2019
# 331     2019-01-01  1196.0     33.44     -82.20     Columbia County  2019
# 332     2019-01-01  1374.0     33.14     -96.81                 NaN  2019
# ...            ...     ...       ...        ...                 ...   ...
# 216187  2019-12-01  2465.0     34.21    -118.88      Ventura County  2019
# 216188  2019-12-01  1087.0     36.95     -76.27        Norfolk city  2019
# 216189  2019-12-01  2535.0     34.28    -118.61  Los Angeles County  2019
# 216190  2019-12-01  1830.0     33.24    -111.70     Maricopa County  2019
# 216191  2019-12-01  4557.0     37.44    -122.15  Santa Clara County  2019
#
#         month  homevalue
# 328         1   403314.0
# 329         1   689765.0
# 330         1    87501.0
# 331         1   192723.0
# 332         1   433910.0
# ...       ...        ...
# 216187     12   720249.0
# 216188     12   210286.0
# 216189     12   662838.0
# 216190     12   427673.0
# 216191     12  4023741.0
#
# [26877 rows x 11 columns],         zipcode      primarycity                                city  \
# 405        7083            Union                        New York, NY
# 406       60126         Elmhurst                         Chicago, IL
# 407       90039      Los Angeles  Los Angeles-Long Beach-Anaheim, CA
# 408       27012         Clemmons                   Winston-Salem, NC
# 409       10006         New York                        New York, NY
# ...         ...              ...                                 ...
# 216256    33781    Pinellas Park                           Tampa, FL
# 216257    33174            Miami           Miami-Fort Lauderdale, FL
# 216258    98005         Bellevue                         Seattle, WA
# 216259    32826          Orlando                         Orlando, FL
# 216260    95605  West Sacramento                      Sacramento, CA
#
#               date    rent  latitude  longitude              county  year  \
# 405     2020-01-01  2224.0     40.69     -74.26        Union County  2020
# 406     2020-01-01  1894.0     41.89     -87.94       DuPage County  2020
# 407     2020-01-01  2907.0     34.11    -118.26  Los Angeles County  2020
# 408     2020-01-01  1358.0     36.02     -80.38      Forsyth County  2020
# 409     2020-01-01  3407.0     40.71     -74.01     New York County  2020
# ...            ...     ...       ...        ...                 ...   ...
# 216256  2020-12-01  1449.0     27.84     -82.71     Pinellas County  2020
# 216257  2020-12-01  1881.0     25.76     -80.36   Miami-Dade County  2020
# 216258  2020-12-01  2175.0     47.62    -122.16         King County  2020
# 216259  2020-12-01  1651.0     28.59     -81.18       Orange County  2020
# 216260  2020-12-01  1985.0     38.59    -121.54         Yolo County  2020
#
#         month  homevalue
# 405         1   354168.0
# 406         1   432226.0
# 407         1  1065315.0
# 408         1   244130.0
# 409         1   888722.0
# ...       ...        ...
# 216256     12   214988.0
# 216257     12   311186.0
# 216258     12  1277233.0
# 216259     12   264649.0
# 216260     12   338108.0
#
# [26761 rows x 11 columns],         zipcode       primarycity                                city  \
# 479       60617           Chicago                         Chicago, IL
# 480       29445       Goose Creek                      Charleston, SC
# 481       19382      West Chester                    Philadelphia, PA
# 482       89129         Las Vegas                       Las Vegas, NV
# 483       23188      Williamsburg                  Virginia Beach, VA
# ...         ...               ...                                 ...
# 216299    89044         Henderson                       Las Vegas, NV
# 216300    76018         Arlington               Dallas-Fort Worth, TX
# 216301    33146             Miami           Miami-Fort Lauderdale, FL
# 216302    80922  Colorado Springs                Colorado Springs, CO
# 216303    91324        Northridge  Los Angeles-Long Beach-Anaheim, CA
#
#               date    rent  latitude  longitude              county  year  \
# 479     2021-01-01  1270.0     41.72     -87.55         Cook County  2021
# 480     2021-01-01  1436.0     32.98     -79.99     Berkeley County  2021
# 481     2021-01-01  1650.0     39.95     -75.60      Chester County  2021
# 482     2021-01-01  1577.0     36.23    -115.29        Clark County  2021
# 483     2021-01-01  1499.0     37.35     -76.77   James City County  2021
# ...            ...     ...       ...        ...                 ...   ...
# 216299  2021-11-01  2308.0     35.90    -115.18        Clark County  2021
# 216300  2021-11-01  1991.0     32.67     -97.10      Tarrant County  2021
# 216301  2021-11-01  3120.0     25.72     -80.27   Miami-Dade County  2021
# 216302  2021-12-01  1903.0     38.89    -104.70      El Paso County  2021
# 216303  2021-12-01  2435.0     34.24    -118.55  Los Angeles County  2021
#
#         month  homevalue
# 479         1   149424.0
# 480         1   220652.0
# 481         1   484781.0
# 482         1   332603.0
# 483         1   341796.0
# ...       ...        ...
# 216299     11   512048.0
# 216300     11   278184.0
# 216301     11  1226386.0
# 216302     12   454701.0
# 216303     12   874441.0
#
# [26296 rows x 11 columns],         zipcode    primarycity                               city        date  \
# 547       78130  New Braunfels                    San Antonio, TX  2022-01-01
# 548       78613     Cedar Park                         Austin, TX  2022-01-01
# 549       30024        Suwanee                        Atlanta, GA  2022-01-01
# 550       23235       Richmond                       Richmond, VA  2022-01-01
# 551       34243       Sarasota  North Port-Sarasota-Bradenton, FL  2022-01-01
# ...         ...            ...                                ...         ...
# 216305    80205         Denver                         Denver, CO  2022-01-01
# 216306    27607        Raleigh                        Raleigh, NC  2022-01-01
# 216307    23231        Henrico                       Richmond, VA  2022-02-01
# 216308    95823     Sacramento                     Sacramento, CA  2022-03-01
# 216309    85704         Tucson                         Tucson, AZ  2022-03-01
#
#           rent  latitude  longitude               county  year  month  \
# 547     1586.0     29.70     -98.11         Comal County  2022      1
# 548     1713.0     30.51     -97.83    Williamson County  2022      1
# 549     2060.0     34.05     -84.07      Gwinnett County  2022      1
# 550     1615.0     37.51     -77.56  Chesterfield County  2022      1
# 551     2507.0     27.40     -82.53       Manatee County  2022      1
# ...        ...       ...        ...                  ...   ...    ...
# 216305  1942.0     39.76    -104.96        Denver County  2022      1
# 216306  1608.0     35.81     -78.72          Wake County  2022      1
# 216307  1439.0     37.44     -77.32       Henrico County  2022      2
# 216308  2233.0     38.47    -121.44    Sacramento County  2022      3
# 216309  1683.0     32.33    -110.98          Pima County  2022      3
#
#         homevalue
# 547      339578.0
# 548      587541.0
# 549      535073.0
# 550      333192.0
# 551      416486.0
# ...           ...
# 216305   665441.0
# 216306   623499.0
# 216307   276453.0
# 216308   449515.0
# 216309   438869.0
#
# [6595 rows x 11 columns]]

# %%
X = house.homevalue.values.reshape(-1, 1)

# %%
X[:5]
# Out:
# array([[393085.],
#        [252566.],
#        [216309.],
#        [541022.],
#        [190597.]])

# %%
X.shape
# Out:
# (216608, 1)

# %%
y = house.rent

# %%
model = LinearRegression()

# %%
model.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X)
print(y_pred.shape)
# Out:
# (216608,)

# %%
plt.scatter(X, y)
plt.plot(X, y_pred, color='red')
plt.show()

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [0.00149482]
# 1011.8779539222144

# %% [markdown]
# # Getting

# %%
# Create our features
X = house.drop(columns=["rent","primarycity","city", "county","date"])
X = pd.get_dummies(X)


# Create our target
y = house["rent"]

# %%
X.describe()
# Out:
#              zipcode       latitude      longitude           year  \
# count  216608.000000  216608.000000  216608.000000  216608.000000
# mean    54924.910830      35.505987     -94.443329    2017.683437
# std     30846.015989       5.351203      17.671219       2.361714
# min      1604.000000      21.270000    -158.080000    2014.000000
# 25%     30022.000000      32.790000    -112.310000    2016.000000
# 50%     48326.000000      34.300000     -87.620000    2018.000000
# 75%     85653.000000      39.690000     -80.200000    2020.000000
# max     99206.000000      48.180000     -70.660000    2022.000000
#
#                month     homevalue
# count  216608.000000  2.166080e+05
# mean        6.377553  4.384376e+05
# std         3.479039  4.043536e+05
# min         1.000000  1.943100e+04
# 25%         3.000000  2.112858e+05
# 50%         6.000000  3.163100e+05
# 75%         9.000000  5.126048e+05
# max        12.000000  5.990842e+06

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=.25, random_state=12,)

# %%
# Train the Logistic Regression model using the resampled data
from sklearn.linear_model import LogisticRegression
log_reg = LogisticRegression(solver='lbfgs', random_state=1)
log_reg
# Out:
# LogisticRegression(random_state=1)

# %%
log_reg.fit(X_train, y_train)

# %%
# Calculated the balanced accuracy score
y_pred =log_reg.predict(X_test)

from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, y_pred))

# %%
# Display the confusion matrix

confusion_matrix(y_test, y_pred)

# %%
# Print the imbalanced classification report
from imblearn.metrics import classification_report_imbalanced
print(classification_report_imbalanced(y_test, y_pred))

# %% [markdown]
# # OVERSAMPING

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.25, random_state=12)
X_train.shape

# %%
# Resample the training data with the RandomOversampler
from imblearn.over_sampling import RandomOverSampler
ros = RandomOverSampler(random_state=12)
X_resampled, y_resampled = ros.fit_resample(X_train, y_train)

# %%
# Train the Logistic Regression model using the resampled data
from sklearn.linear_model import LogisticRegression
log_reg = LogisticRegression(solver='lbfgs', random_state=1)
log_reg.fit(X_resampled, y_resampled)

# %%
# Calculated the balanced accuracy score
y_pred =log_reg.predict(X_test)

from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)

# %%
# Display the confusion matrix

confusion_matrix(y_test, y_pred)
